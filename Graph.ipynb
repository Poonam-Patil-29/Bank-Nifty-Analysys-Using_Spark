# %%
from pyspark.sql import *
import findspark
findspark.init()
import pyspark
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName('demo').getOrCreate()
df=spark.read.csv("C:\\Users\\ASUS\\Desktop\\Project P1\\banknifty_data.csv",inferSchema=True,header=True)
a = df.select(df.open.alias("NIFTY OPEN"),"high","low","close").filter(df["close"] > 5000).toPandas()
a.plot(x = "low", y = "high", kind = "bar",color="orange")
# Out:
# <AxesSubplot:xlabel='low'>

# %%
plt.figure(figsize = (3, 6))
sb.barplot(x = 'open', y = 'close', data = pandas_df)
plt.title('open vs close')
# Out:
# Text(0.5, 1.0, 'open vs close')

# %%
import findspark
findspark.init()
import pyspark
import pandas
import seaborn as sb
import matplotlib.pyplot as plt
from pyspark.sql import *
spark = SparkSession.builder.getOrCreate()
from pyspark.sql.functions import *
pandas_df=df.toPandas()
df.select("open","low").toPandas().plot(kind="hist",x="open",y="low",title="Open Low Trend",color="pink")
# Out:
# <AxesSubplot:title={'center':'Open Low Trend'}, ylabel='Frequency'>

# %%
df.select("open","high").toPandas().plot(x="open",y="high",title="Open and High")
# Out:
# <AxesSubplot:title={'center':'Open and High'}, xlabel='open'>

# %%
plt.figure(figsize = (6, 6))
sb.barplot(x = 'range_HL', y = 'range_OC', data = pandas_df,color="red")
plt.title('HL vs OC')
# Out:
# Text(0.5, 1.0, 'HL vs OC')

# %%
plt.figure(figsize = (3, 6))
sb.barplot(x = 'open', y = 'close', data = pandas_df,color="green")
plt.title('open vs close')
# Out:
# Text(0.5, 1.0, 'open vs close')

# %%
import findspark
findspark.init()
import pyspark
import pandas
import seaborn as sb
import matplotlib.pyplot as plt
from pyspark.sql import *
spark = SparkSession.builder.getOrCreate()
from pyspark.sql.functions import *
pandas_df=df.toPandas()
df.select("close","high").toPandas().plot(kind="hist",x="close",y="high",title="Close High Trend",color="lime")
# Out:
# <AxesSubplot:title={'center':'Close High Trend'}, ylabel='Frequency'>
